# %%
# Exploratory Data Analysis
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib as Path
import sqlalchemy as sql

# %%
# Load the ratings-sales data
df_review=pd.read_csv("vgratings_2004_2008.csv", encoding = "latin1")
df_review
# Out:
#                                    Name Platform  Year_of_Release  \
# 0                007: Quantum of Solace     X360             2008
# 1                007: Quantum of Solace      PS3             2008
# 2                007: Quantum of Solace      Wii             2008
# 3                007: Quantum of Solace      PS2             2008
# 4                007: Quantum of Solace       DS             2008
# ...                                 ...      ...              ...
# 5326  Zoo Tycoon 2: Ultimate Collection       PC             2008
# 5327                      Zoo Tycoon DS       DS             2005
# 5328        Zoo Vet: Endangered Animals       DS             2008
# 5329                               Zubo       DS             2008
# 5330                             Zwei!!      PSP             2008
#
#              Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0           Action              Activision      0.82      0.51      0.01
# ...

# %%
# Load the ratings-sales data
df_sales=pd.read_csv("vgsales_2004_2008.csv", encoding = "latin1")
df_sales
# Out:
#                                    Name Platform  Year         Genre  \
# 0                007: Quantum of Solace     X360  2008        Action
# 1                007: Quantum of Solace      PS3  2008        Action
# 2                007: Quantum of Solace      Wii  2008        Action
# 3                007: Quantum of Solace      PS2  2008        Action
# 4                007: Quantum of Solace       DS  2008        Action
# ...                                 ...      ...   ...           ...
# 5337  Zoo Tycoon 2: Ultimate Collection       PC  2008      Strategy
# 5338                      Zoo Tycoon DS       DS  2005      Strategy
# 5339        Zoo Vet: Endangered Animals       DS  2008    Simulation
# 5340                               Zubo       DS  2008          Misc
# 5341                             Zwei!!      PSP  2008  Role-Playing
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
engine=sql.create_engine('postgresql://postgres:Anaya2018!@localhost:5432/Video_GamesDB')

# %%
df_review.to_sql('reviews', con=engine, index=False, if_exists='replace')
# Out:
# 331

# %%
df_sales.to_sql('sales', con=engine, index=False, if_exists='replace')
# Out:
# 342

# %%
# reading data from postgre to DF

sales_df=pd.read_sql_table('sales', con=engine)

sales_df.dtypes
# Out:
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
reviews_df=pd.read_sql_table('reviews', con=engine)

reviews_df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release      int64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
Video_Games_Final_df=pd.read_csv("Video_Games_Final.csv", encoding = "latin1")
Video_Games_Final_df
# Out:
#                    game_name platform  year_of_release     genre  \
# 0     007: Quantum of Solace     X360             2008    Action
# 1     007: Quantum of Solace      PS3             2008    Action
# 2     007: Quantum of Solace      Wii             2008    Action
# 3     007: Quantum of Solace       PC             2008    Action
# 4                  1 vs. 100       DS             2008      Misc
# ...                      ...      ...              ...       ...
# 2746              Zoo Keeper       DS             2004    Puzzle
# 2747            Zoo Tycoon 2       PC             2004  Strategy
# 2748         Zoo Tycoon 2 DS       DS             2008  Strategy
# 2749           Zoo Tycoon DS       DS             2005  Strategy
# 2750                    Zubo       DS             2008      Misc
#
#                    publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0                 Activision      0.82      0.51      0.01         0.14
# ...

# %%
Video_Games_Final_df.to_sql('Video_Games_Final', con=engine, index=False, if_exists='replace')
# Out:
# 751
